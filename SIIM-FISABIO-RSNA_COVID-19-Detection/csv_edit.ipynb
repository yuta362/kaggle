# %%
import pandas as pd

csv = pd.read_csv('merge_csv.csv')
csv.head()
# Out:
#    Unnamed: 0                id  \
# 0           0  000a312787f2.dcm
# 1           1  000c3a3f293f.dcm
# 2           2  0012ff7358bc.dcm
# 3           3  001398f4ff4f.dcm
# 4           4  001bd15d1891.dcm
#
#                                                boxes  \
# 0  [{'x': 789.28836, 'y': 582.43035, 'width': 102...
# 1                                                NaN
# 2  [{'x': 677.42216, 'y': 197.97662, 'width': 867...
# 3  [{'x': 2729, 'y': 2181.33331, 'width': 948.000...
# 4  [{'x': 623.23328, 'y': 1050, 'width': 714, 'he...
#
#                                                label StudyInstanceUID  \
# 0  opacity 1 789.28836 582.43035 1815.94498 2499....     5776db0cec75
# 1                                     none 1 0 0 1 1     ff0879eb20ed
# 2  opacity 1 677.42216 197.97662 1545.21983 1197....     9d514ce429a7
# 3    opacity 1 2729 2181.33331 3677.00012 2785.33331     28dddc8559b2
# 4  opacity 1 623.23328 1050 1337.23328 2156 opaci...     dfd9fdd85a3e
#
# ...

# %%
img_id = csv['id'].str.replace('.dcm', '_img')
study_id = csv['StudyInstanceUID'] + '_study'
file_path = csv['img_path']

df = pd.DataFrame({'img_id':img_id,
                   'study_id':study_id,
                   'file_path:csv':file_path}) 
df.head()
# Out:
# <ipython-input-23-3e6563c2aab1>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   img_id = csv['id'].str.replace('.dcm', '_img')
#              img_id            study_id  \
# 0  000a312787f2_img  5776db0cec75_study
# 1  000c3a3f293f_img  ff0879eb20ed_study
# 2  0012ff7358bc_img  9d514ce429a7_study
# 3  001398f4ff4f_img  28dddc8559b2_study
# 4  001bd15d1891_img  dfd9fdd85a3e_study
#
#                                        file_path:csv
# 0  /Volumes/Samsung_T5/siim-covid19-detection/tra...
# 1  /Volumes/Samsung_T5/siim-covid19-detection/tra...
# 2  /Volumes/Samsung_T5/siim-covid19-detection/tra...
# 3  /Volumes/Samsung_T5/siim-covid19-detection/tra...
# 4  /Volumes/Samsung_T5/siim-covid19-detection/tra...
